# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/state-reducers.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239428-lesson-2-state-reducers)

# %% [markdown]
# # State Reducers
#
# ## Review
#
# We covered a few different ways to define LangGraph state schema, including `TypedDict`, `Pydantic`, or `Dataclasses`.
#
# ## Goals
#
# Now, we're going to dive into reducers, which specify how state updates are performed on specific keys / channels in the state schema.

# %%
# %%capture --no-stderr
# %pip install --quiet -U langchain_core langgraph

# %% [markdown]
# ## Default overwriting state
#
# Let's use a `TypedDict` as our state schema.

# %%
from typing_extensions import TypedDict
from IPython.display import Image, display
from langgraph.graph import StateGraph, START, END

class State(TypedDict):
    int_play: int
    
def node_1(state):
    print("=== NODE 1 ===")
    return {"int_play": state['int_play'] + 1}


builder = StateGraph(State)
builder.add_node("node_1", node_1)
builder.add_edge(START, "node_1")
builder.add_edge("node_1", END)

graph = builder.compile()

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
graph.invoke({"int_play": 1})
# Out:
# === NODE 1 ===
# {'int_play': 2}

# %% [markdown]
# Let's look at the state update, `return {"int_play": state['int_play'] + 1}`.
#
# As discussed before, by default LangGraph doesn't know the preferred way to update the state.
#
# So, it will just overwrite the value of `int_play` in `node_1`:
#
# ```
# return {"int_play": state['int_play'] + 1}
# ```
#
# If we pass `{'int_play': 1}` as input, the state returned from the graph is `{'int_play': 2}`.
#
# ## Branching
#
# Let's look at a case where our nodes branch.

# %%
class State(TypedDict):
    int_play: int

def node_1(state):
    print("---Node 1---")
    return {"int_play": state['int_play'] + 1}

def node_2(state):
    print("---Node 2---")
    return {"int_play": state['int_play'] + 1}

def node_3(state):
    print("---Node 3---")
    return {"int_play": state['int_play'] + 1}

# Build graph
builder = StateGraph(State)
builder.add_node("node_1", node_1)
builder.add_node("node_2", node_2)
builder.add_node("node_3", node_3)

# Logic
builder.add_edge(START, "node_1")
builder.add_edge("node_1", "node_2")
builder.add_edge("node_1", "node_3")
builder.add_edge("node_2", END)
builder.add_edge("node_3", END)

# Add
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
from langgraph.errors import InvalidUpdateError
try:
    graph.invoke({"int_play" : 1})
except InvalidUpdateError as e:
    print(f"InvalidUpdateError occurred: {e}")
# Out:
# ---Node 1---
# ---Node 2---
# ---Node 3---
# InvalidUpdateError occurred: At key 'int_play': Can receive only one value per step. Use an Annotated key to handle multiple values.
# For troubleshooting, visit: https://docs.langchain.com/oss/python/langgraph/errors/INVALID_CONCURRENT_GRAPH_UPDATE

# %% [markdown]
# We see a problem!
#
# Node 1 branches to nodes 2 and 3.
#
# Nodes 2 and 3 run in parallel, which means they run in the same step of the graph.
#
# They both attempt to overwrite the state *within the same step*.
#
# This is ambiguous for the graph! Which state should it keep?

# %% [markdown]
# ## Reducers
#
# [Reducers](https://docs.langchain.com/oss/python/langgraph/graph-api/#reducers) give us a general way to address this problem.
#
# They specify how to perform updates.
#
# We can use the `Annotated` type to specify a reducer function.
#
# For example, in this case let's append the value returned from each node rather than overwriting them.
#
# We just need a reducer that can perform this: `operator.add` is a function from Python's built-in operator module.
#
# When `operator.add` is applied to lists, it performs list concatenation.

# %%
from operator import add
from typing import Annotated

class State(TypedDict):
    int_play: Annotated[list[int], add]

def node_1(state):
    print("---Node 1---")
    return {"int_play": [state['int_play'][0] + 1]}


builder = StateGraph(State)
builder.add_node("node_1", node_1)
builder.add_edge(START, "node_1")
builder.add_edge("node_1", END)

graph = builder.compile()


display(Image(graph.get_graph().draw_mermaid_png()))

# %%
graph.invoke({"int_play" : [1]})
# not overwriting, rather, i am appending a new value to this list
# Out:
# ---Node 1---
# {'int_play': [1, 2]}

# %% [markdown]
# Now, our state key `int_play` is a list.
#
# This `operator.add` reducer function will append updates from each node to this list.

# %%
def node_1(state):
    print("---Node 1---")
    return {"int_play": [state['int_play'][-1] + 1]}

def node_2(state):
    print("---Node 2---")
    return {"int_play": [state['int_play'][-1] + 1]}

def node_3(state):
    print("---Node 3---")
    return {"int_play": [state['int_play'][-1] + 1]}

# Build graph
builder = StateGraph(State)
builder.add_node("node_1", node_1)
builder.add_node("node_2", node_2)
builder.add_node("node_3", node_3)

# Logic
builder.add_edge(START, "node_1")
builder.add_edge("node_1", "node_2")
builder.add_edge("node_1", "node_3")
builder.add_edge("node_2", END)
builder.add_edge("node_3", END)

# Add
graph = builder.compile()

# View
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# We can see that updates in nodes 2 and 3 are performed concurrently because they are in the same step.

# %%
graph.invoke({"int_play" : [1]})
# Out:
# ---Node 1---
# ---Node 2---
# ---Node 3---
# {'int_play': [1, 2, 3, 3]}

# %% [markdown]
# Now, let's see what happens if we pass `None` to `int_play`.
#
# We see an error because our reducer, `operator.add`, attempts to concatenate `NoneType` pass as input to list in `node_1`.

# %%
try:
    graph.invoke({"int_play" : None})
except TypeError as e:
    print(f"TypeError occurred: {e}")
# Out:
# TypeError occurred: can only concatenate list (not "NoneType") to list

# %% [markdown]
# ## Custom Reducers
#
# To address cases like this,[we can also define custom reducers](https://docs.langchain.com/oss/python/langgraph/use-graph-api#process-state-updates-with-reducers).
#
# For example, lets define custom reducer logic to combine lists and handle cases where either or both of the inputs might be `None`.

# %%
def reduce_list(left: list | None, right: list | None) -> list:
    """Safely combine two lists, handling cases where either or both inputs might be None.

    Args:
        left (list | None): The first list to combine, or None.
        right (list | None): The second list to combine, or None.

    Returns:
        list: A new list containing all elements from both input lists.
               If an input is None, it's treated as an empty list.
    """
    if not left:
        left = []
    if not right:
        right = []
    return left + right

class DefaultState(TypedDict):
    int_play: Annotated[list[int], add]

class CustomReducerState(TypedDict):
    int_play: Annotated[list[int], reduce_list]

# %%
builder = StateGraph(DefaultState)
builder.add_node("node_1", node_1)

builder.add_edge(START, "node_1")
builder.add_edge("node_1", END)

graph = builder.compile()

display(Image(graph.get_graph().draw_mermaid_png()))

try:
    print(graph.invoke({"int_play" : None}))
except TypeError as e:
    print(f"TypeError occurred: {e}")
# Out:
# TypeError occurred: can only concatenate list (not "NoneType") to list

# %% [markdown]
# Now, try with our custom reducer. We can see that no error is thrown.

# %%
builder = StateGraph(CustomReducerState)
builder.add_node("node_1", node_1)

builder.add_edge(START, "node_1")
builder.add_edge("node_1", END)

graph = builder.compile()

display(Image(graph.get_graph().draw_mermaid_png()))

try:
    print(graph.invoke({"int_play" : None}))
except TypeError as e:
    print(f"TypeError occurred: {e}")
# Out:
# ---Node 1---
# {'int_play': [2]}

# %% [markdown]
# ## Messages
#
# In module 1, we showed how to use a built-in reducer, `add_messages`, to handle messages in state.
#
# We also showed that [`MessagesState` is a useful shortcut if you want to work with messages](https://docs.langchain.com/oss/python/langgraph/use-graph-api#messagesstate).
#
# * `MessagesState` has a built-in `messages` key
# * It also has a built-in `add_messages` reducer for this key
#
# These two are equivalent.
#
# We'll use the `MessagesState` class via `from langgraph.graph import MessagesState` for brevity.

# %%
from typing import Annotated
from langgraph.graph import MessagesState # built in with messsages key and add_messages reducer function
from langchain_core.messages import AnyMessage
from langgraph.graph.message import add_messages

# Define a custom TypedDict that includes a list of messages with add_messages reducer
class CustomMessagesState(TypedDict):
    messages: Annotated[list[AnyMessage], add_messages]
    # arbitrary keys
    added_key_1: str
    added_key_2: str
    # etc

# Use MessagesState, which includes the messages key with add_messages reducer: messages: Annotated[list[AnyMessage], add_messages]
class ExtendedMessagesState(MessagesState):
    # Add any keys needed beyond messages, which is pre-built 
    added_key_1: str
    added_key_2: str
    # etc

# %%
from typing import Annotated
from langchain_core.messages import AnyMessage
from langgraph.graph.message import add_messages
from langgraph.graph import MessagesState

class ExtendedMessagesState(MessagesState): # equivalent to messages: Annotated[List[AnyMessage], add_messages]
    # can add more arbitrary keys
    add_key_1: str

# %% [markdown]
# Let's talk a bit more about usage of the `add_messages` reducer.

# %%
from langchain_core.messages import AIMessage, HumanMessage
from langgraph.graph.message import add_messages

initial_messages = [
    AIMessage(content = "Hi, how can i assist you?", name = "Model"),
    HumanMessage(content = "I need your assistance with writing an email to my school principal", name = "Shiv")
]

new_message = AIMessage(content="Sure, I can help with that. What is the topic about?", name = "Model")

add_messages(initial_messages, new_message)
# Out:
# [AIMessage(content='Hi, how can i assist you?', additional_kwargs={}, response_metadata={}, name='Model', id='c16c3c98-b257-4add-b602-eb914785970f'),
#  HumanMessage(content='I need your assistance with writing an email to my school principal', additional_kwargs={}, response_metadata={}, name='Shiv', id='c4d7bf69-05e5-4c4a-ac15-e5b480c93723'),
#  AIMessage(content='Sure, I can help with that. What is the topic about?', additional_kwargs={}, response_metadata={}, name='Model', id='19e8751b-4666-441b-ba66-2ff58b933f18')]

# %% [markdown]
# So we can see that `add_messages` allows us to append messages to the `messages` key in our state.
#
# ### Re-writing
#
# Let's show some useful tricks when working with the `add_messages` reducer.
#
# If we pass a message with the same ID as an existing one in our `messages` list, it will get overwritten!

# %%
from langchain_core.messages import AIMessage, HumanMessage
from langgraph.graph.message import add_messages

initial_messages = [
    AIMessage(content = "Hi, how can i assist you?", name = "Model", id = 1),
    HumanMessage(content = "I need your assistance with writing an email to my school principal", name = "Shiv", id = 2)
]

# overwriting
new_message = HumanMessage(content="Help me write an email to my school princiapl on What is the best way to win a Gold Medal for studies?", name = "Shiv", id = 2)

add_messages(initial_messages, new_message)
# Out:
# [AIMessage(content='Hi, how can i assist you?', additional_kwargs={}, response_metadata={}, name='Model', id='1'),
#  HumanMessage(content='Help me write an email to my school princiapl on What is the best way to win a Gold Medal for studies?', additional_kwargs={}, response_metadata={}, name='Shiv', id='2')]

# %% [markdown]
# ### Removal
#
# We can remove messages by using [RemoveMessage](https://docs.langchain.com/oss/python/langgraph/add-memory#delete-messages).

# %%
from langchain_core.messages import RemoveMessage

# Message list
messages = [AIMessage("Hi.", name="Bot", id="1")]
messages.append(HumanMessage("Hi.", name="Shiv", id="2"))
messages.append(AIMessage("So you said you want to write an email?", name="Bot", id="3"))
messages.append(HumanMessage("Yes, I want to write an email on how to win a Gold medal for studies", name="Shiv", id="4"))
messages.append(AIMessage("Awesome drive, that's's great motivation", name="Bot", id="5"))
messages.append(HumanMessage("Thank you, please make it formal and concise.", name="Shiv", id="6"))

# Isolate messages to delete; remove all but the 2 most recent messages
delete_messages = [RemoveMessage(id=m.id) for m in messages[:-2]]
print(delete_messages)
# Out:
# [RemoveMessage(content='', additional_kwargs={}, response_metadata={}, id='1'), RemoveMessage(content='', additional_kwargs={}, response_metadata={}, id='2'), RemoveMessage(content='', additional_kwargs={}, response_metadata={}, id='3'), RemoveMessage(content='', additional_kwargs={}, response_metadata={}, id='4')]

# %%
add_messages(messages , delete_messages)
# Out:
# [AIMessage(content="Awesome drive, that's's great motivation", additional_kwargs={}, response_metadata={}, name='Bot', id='5'),
#  HumanMessage(content='Thank you, please make it formal and concise.', additional_kwargs={}, response_metadata={}, name='Shiv', id='6')]

# %% [markdown]
# We can see that mesage IDs 1 and 2, as noted in `delete_messages` are removed by the reducer.
#
# We'll see this put into practice a bit later.
